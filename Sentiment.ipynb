# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q findspark
# !pip install -q pyspark

# %%
from pyspark import SparkContext
from pyspark.sql import SQLContext

# %%
sc = SparkContext()

# %%
sql = SQLContext(sc)

# %%
reviews = sql.read.json("/content/drive/MyDrive/PersonalProjects/reviews_Cell_Phones_and_Accessories_5.json")

# %% [markdown]
# We have loaded the dataset. Now, we need to remove the unwanted columns so that we only have those columns that are needed to perform sentiment analysis.

# %%
reviews = reviews.drop('asin').drop('helpful').drop('summary').drop('unixReviewTime').drop('reviewTime')
reviews.show(25)
# Out:
# +-------+--------------------+--------------+--------------------+
# |overall|          reviewText|    reviewerID|        reviewerName|
# +-------+--------------------+--------------+--------------------+
# |    4.0|They look good an...|A30TL5EWN6DFXT|           christina|
# |    5.0|These stickers wo...| ASY55RVNIL0UD|            emily l.|
# |    5.0|These are awesome...|A2TMXE2AFO7ONB|               Erica|
# |    4.0|Item arrived in g...| AWJ0WZQYMYFQ4|                  JM|
# |    5.0|awesome! stays on...| ATX7CZYFXI1KW|    patrice m rogoza|
# |    3.0|These make using ...| APX47D16JOP7H|                 RLH|
# |    5.0|Came just as desc...|A1JVVYYO7G56DS|         Tyler Evans|
# |    1.0|it worked for the...| A6FGO4TBZ3QFZ|    Abdullah Albyati|
# |    5.0|Good case, solid ...|A2JWEDW5FSVB0F|                Adam|
# |    5.0|This is a fantast...| A8AJS1DW7L3JJ|     Agata Majchrzak|
# |    5.0|this case fits pe...|A2YO4SCWAWNYBI|       Alex Maslakov|
# |    5.0|This is the first...|A3AFELPYTZH90T|           Baja Alan|
# |    5.0|Performs exactly ...| A6Q0P54QSP11J|       Olivia ysiak|
# |    5.0|Unlike Most of th...| ANMATY0L0HX6Y|        Sasha Malkin|
# |    5.0|Just what I neede...|A1XBPVR8FE7TE1|               tim g|
# |    5.0|When there is no ...|A35C4777EXZZQH|           Viktoriya|
# |    5.0|It works great. D...| ACU3LCRX4A8RV|Zonaldo Reefey "Z...|
# |    5.0|Surprisingly, thi...|A1ZTTNS6SWFV52|Alexander Graham ...|
# |    5.0|I have tested thi...|A38EHCCO532RYI|          amazonfan1|
# |    1.0|It worked great f...|A2INSXDTE08WSJ|              Barbie|
# |    5.0|I love that it ha...| A9NETBZNEW2TP|Bernadette Mitche...|
# |    5.0|just what you nee...|A385HZRPXDDFCL|                 Bob|
# |    3.0|does not have the...| ALZQ9D8V53TI2|         Bruce/Emily|
# |    4.0|They are nothing ...|A3VWU7S29LR2XX|             Bryan S|
# |    4.0|I have several ch...|A3TOHPW7ES23NZ|               Cathy|
# +-------+--------------------+--------------+--------------------+
# only showing top 25 rows

# %% [markdown]
# Let's re-order the columns so that it's easier to perform the sentiment analysis.

# %%
reviews = reviews.select('reviewerID','reviewerName','reviewText','overall')

# %%
reviews.show(25)
# Out:
# +--------------+--------------------+--------------------+-------+
# |    reviewerID|        reviewerName|          reviewText|overall|
# +--------------+--------------------+--------------------+-------+
# |A30TL5EWN6DFXT|           christina|They look good an...|    4.0|
# | ASY55RVNIL0UD|            emily l.|These stickers wo...|    5.0|
# |A2TMXE2AFO7ONB|               Erica|These are awesome...|    5.0|
# | AWJ0WZQYMYFQ4|                  JM|Item arrived in g...|    4.0|
# | ATX7CZYFXI1KW|    patrice m rogoza|awesome! stays on...|    5.0|
# | APX47D16JOP7H|                 RLH|These make using ...|    3.0|
# |A1JVVYYO7G56DS|         Tyler Evans|Came just as desc...|    5.0|
# | A6FGO4TBZ3QFZ|    Abdullah Albyati|it worked for the...|    1.0|
# |A2JWEDW5FSVB0F|                Adam|Good case, solid ...|    5.0|
# | A8AJS1DW7L3JJ|     Agata Majchrzak|This is a fantast...|    5.0|
# |A2YO4SCWAWNYBI|       Alex Maslakov|this case fits pe...|    5.0|
# |A3AFELPYTZH90T|           Baja Alan|This is the first...|    5.0|
# | A6Q0P54QSP11J|       Olivia ysiak|Performs exactly ...|    5.0|
# | ANMATY0L0HX6Y|        Sasha Malkin|Unlike Most of th...|    5.0|
# |A1XBPVR8FE7TE1|               tim g|Just what I neede...|    5.0|
# |A35C4777EXZZQH|           Viktoriya|When there is no ...|    5.0|
# | ACU3LCRX4A8RV|Zonaldo Reefey "Z...|It works great. D...|    5.0|
# |A1ZTTNS6SWFV52|Alexander Graham ...|Surprisingly, thi...|    5.0|
# |A38EHCCO532RYI|          amazonfan1|I have tested thi...|    5.0|
# |A2INSXDTE08WSJ|              Barbie|It worked great f...|    1.0|
# | A9NETBZNEW2TP|Bernadette Mitche...|I love that it ha...|    5.0|
# |A385HZRPXDDFCL|                 Bob|just what you nee...|    5.0|
# | ALZQ9D8V53TI2|         Bruce/Emily|does not have the...|    3.0|
# |A3VWU7S29LR2XX|             Bryan S|They are nothing ...|    4.0|
# |A3TOHPW7ES23NZ|               Cathy|I have several ch...|    4.0|
# +--------------+--------------------+--------------------+-------+
# only showing top 25 rows

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, Tokenizer
from pyspark.ml.tuning import TrainValidationSplit

# %% [markdown]
# Split the dataset into train and test datasets.

# %%
train, test = reviews.randomSplit([0.9, 0.1], seed=12345)

# %% [markdown]
# Let's create a pipeline. The steps for performing the sentiment analysis includes first aplitting the text into tokens and then hashing these tokens before using the hashes as the input for the logistic regression model. So instead of executing this seperately for each entry, we can rather enter them into pipeline and execute the pipeline for the training data

# %%
tokenizer = Tokenizer(inputCol="reviewText", outputCol="predictions")
hashingTF = HashingTF(inputCol=tokenizer.getOutputCol(), outputCol="features")
lr = LogisticRegression(maxIter=10, regParam=0.001,labelCol='overall')
pipeline = Pipeline(stages=[tokenizer, hashingTF, lr])

# %%
model = pipeline.fit(train)

# %%
actual = test.select('overall')

# %% [markdown]
# Apply the pipeline model to transform the testing dataset.

# %%
prediction = model.transform(test)

# %%
prediction.show()
# Out:
# +--------------------+------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+----------+
# |          reviewerID|      reviewerName|          reviewText|overall|         predictions|            features|       rawPrediction|         probability|prediction|
# +--------------------+------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+----------+
# |A01623621DS97QCLQ...|    Paul A. Nation|this item was bro...|    1.0|[this, item, was,...|(262144,[11941,12...|[-8.4089477788623...|[6.40048219047167...|       1.0|
# |A01623621DS97QCLQ...|    Paul A. Nation|very nice keeps m...|    5.0|[very, nice, keep...|(262144,[5381,223...|[-8.4089304325109...|[2.76422568650299...|       5.0|
# |A027168223K80PQU4...|      brooke rieth|all of them came ...|    5.0|[all, of, them, c...|(262144,[19036,27...|[-8.4092453849753...|[1.06956781429084...|       5.0|
# |A0388397363MZHRU6...|Mustafa alhusseiny|It don't work on ...|    2.0|[it, don't, work,...|(262144,[7062,722...|[-8.4088759486914...|[5.27390487231358...|       3.0|
# |A04645291H50KGR2J...|          MrJizzle|Work in a warehou...|    5.0|[work, in, a, war...|(262144,[9635,162...|[-8.4091219557053...|[4.66139055834338...|       4.0|
# |A0712184E2Z0T1Z4V4ZN|    Angelita Perez|It does not let g...|    4.0|[it, does, not, l...|(262144,[1109,634...|[-8.4105100907958...|[1.07442905875125...|       5.0|
# |A0718784TOWF9DX1DOFD|  Vanessa Williams|...I just found i...|    5.0|[...i, just, foun...|(262144,[5537,612...|[-8.4110109939808...|[2.27836324702543...|       3.0|
# |A0718784TOWF9DX1DOFD|  Vanessa Williams|This is just a ba...|    3.0|[this, is, just, ...|(262144,[5537,694...|[-8.4136120848540...|[3.37627242609951...|       4.0|
# |A09254782VJKWIDD9...|            lamont|would have gave a...|    1.0|[would, have, gav...|(262144,[1917,190...|[-8.4095042689003...|[6.12313641520652...|       2.0|
# |A095279462RKEPKUCAWI|             Nikki|My husband had go...|    5.0|[my, husband, had...|(262144,[11104,12...|[-8.4095156368874...|[2.55036568872817...|       5.0|
# |A0954586PW98I9TNZXJP|          NessaMia|Very sturdy cable...|    5.0|[very, sturdy, ca...|(262144,[12219,19...|[-8.4093544206512...|[4.30440802806866...|       5.0|
# |A1038957GWRBP375RU5T|               leo|2 hair size pins ...|    3.0|[2, hair, size, p...|(262144,[12524,30...|[-8.4089268569526...|[4.53297267554853...|       4.0|
# |      A103D3GYGFHS96|   Daisy Cartagena|I purchased this ...|    1.0|[i, purchased, th...|(262144,[3613,190...|[-8.4088046943620...|[7.13262027633711...|       3.0|
# |      A104R1UFTJNBKK|   Amazon Customer|Attached to Car S...|    5.0|[attached, to, ca...|(262144,[991,4376...|[-8.4091858266978...|[1.52757662774289...|       5.0|
# |      A104R1UFTJNBKK|   Amazon Customer|Great for long tr...|    5.0|[great, for, long...|(262144,[1851,612...|[-8.4088493145166...|[2.29794765093789...|       5.0|
# |      A105K765Z5SX1A|   Springs Shopper|I did a lot of re...|    5.0|[i, did, a, lot, ...|(262144,[3121,678...|[-8.4099374978756...|[8.91036711801998...|       5.0|
# |      A105L5EX9D0NH8|       Dueces Wild|I was a little he...|    5.0|[i, was, a, littl...|(262144,[1546,553...|[-8.4203804350650...|[1.31791891725848...|       5.0|
# |      A106Q1A6LGU4DP|            gnapye|In a day and age ...|    5.0|[in, a, day, and,...|(262144,[1136,425...|[-8.4115554158192...|[1.77176994109010...|       4.0|
# |      A107K10JTO8NSH|            jonnii|I ordered this to...|    2.0|[i, ordered, this...|(262144,[19036,22...|[-8.4096280639068...|[4.70625230479892...|       5.0|
# |      A1086X5YV9M4QF|   Amazon Customer|This is the best ...|    5.0|[this, is, the, b...|(262144,[5381,553...|[-8.4148409119258...|[5.24222605693042...|       5.0|
# +--------------------+------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
total = prediction.count()

# %%
error = 0

# %%
for row in prediction.collect():
  if row['prediction'] < row['overall']-0.2 or row['prediction'] > row['overall']+0.2:
    error += 1

# %%
error /= total
accuracy = 1 - error

# %%
accuracy
# Out:
# 0.9592374278647981
